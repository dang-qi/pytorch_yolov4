# %%
import os
import numpy as np
import random
from cfg_patch import Cfg
import matplotlib.pyplot as plt
from dataset import YoloModanetHumanDataset, draw_box

random.seed(2020)
np.random.seed(2020)
Cfg.dataset_dir = os.path.expanduser('~/data/datasets/modanet/Images/train')
dataset = YoloModanetHumanDataset(Cfg.anno_path, Cfg, train=True)
for i in range(10):
    out_img, out_bboxes = dataset.__getitem__(i)
    a = draw_box(out_img.copy(), out_bboxes.astype(np.int32))
    plt.imshow(a.astype(np.int32))
    plt.show()

# %%
import os
import numpy as np
import random
from cfg_patch import Cfg
import matplotlib.pyplot as plt
from dataset import YoloModanetHumanDataset, draw_box

random.seed(2020)
np.random.seed(2020)
Cfg.dataset_dir = os.path.expanduser('~/data/datasets/modanet/Images/train')
dataset = YoloModanetHumanDataset(Cfg.anno_path, Cfg, train=False)
for i in range(10):
    out_img, targets = dataset.__getitem__(i)
    out_bboxes = targets['boxes_in_human'].numpy()
    #out_bboxes = targets['boxes'].numpy()
    human_boxes = targets['human_box'].numpy()
    
    a = draw_box(out_img.copy(), out_bboxes.astype(np.int32))
    plt.imshow(a.astype(np.int32))
    plt.show()
